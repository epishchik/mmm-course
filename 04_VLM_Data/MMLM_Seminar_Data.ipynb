# %% [markdown]
# # Семинар по данным
#
# Сегодня на семинаре мы научимся запускать и оценивать VLM (Vision-Language Models) на бенчмарках в Google Colab.
#
# **Цель:**
# Освоить базовые шаги работы с инструментом lmm-eval: запустить его, протестировать модель на стандартных бенчмарках, а также собрать свой небольшой бенчмарк и оценить модель на нём.
#
# **План:**
# - Установим lmm-eval и выберем модель.
# - Прогоним модель на готовых бенчмарках.
# - Сделаем свой мини-бенчмарк и посмотрим, как справляется модель.
# - Улучшим дистракторы через доп модель
# - Разберёмся, как анализировать результаты.
#
# **Важно:**  Не забудьте выбрать среду исполнения с GPU

# %% [markdown]
# # Загружаем LMMs-Eval + зависимости

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install -U accelerate

# !git clone https://github.com/EvolvingLMMs-Lab/lmms-eval.git

# %cd lmms-eval
# !pip install -e .
# %cd ..

# %%
import os
os.environ['HF_TOKEN'] = "..." # Токен с только что созданного аккаунта
# settings -> access tokens -> create
# для работы с hugging face датасетами

# %% [markdown]
# # Запуск модели на бенчмарке (-ах)
#
# Хотим померить качество модели на бенчмарке mmmu
#
# Все конфиги бенчмарков лежат в lmms-eval/lmms_eval/tasks \
# Все конфиги моделей лежат в lmms-eval/lmms_eval/models

# %%
# !python3 -m accelerate.commands.launch \
            --num_processes=1 \
            -m lmms_eval \
            --model qwen2_vl \
            --model_args "pretrained=Qwen/Qwen2-VL-2B-Instruct" \
            --tasks mmmu \
            --batch_size 1 \
            --log_samples \
            --log_samples_suffix test \
            --output_path ./logs/ \
            --limit 300

# %%
# Сохранённый результат команды выше
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-10-22 14:23:27.810962: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761143007.844239    9479 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761143007.854133    9479 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761143007.878359    9479 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761143007.878407    9479 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761143007.878414    9479 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761143007.878421    9479 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-22 14:23:27.885223: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 14:23:33 | INFO     | __main__:cli_evaluate:311 - Verbosity set to INFO
# 2025-10-22 14:23:36 | INFO     | __main__:cli_evaluate_single:400 - Evaluation tracker args: {'output_path': './logs/'}
# 2025-10-22 14:23:36 | WARNING  | __main__:cli_evaluate_single:430 -  --limit SHOULD ONLY BE USED FOR TESTING.REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2025-10-22 14:23:36 | INFO     | __main__:cli_evaluate_single:480 - Selected Tasks: ['mmmu']
# 2025-10-22 14:23:36 | INFO     | lmms_eval.evaluator:simple_evaluate:161 - Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:16<00:00,  8.42s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# 2025-10-22 14:23:59 | INFO     | lmms_eval.evaluator:evaluate:402 - Running on rank 0 (local rank 0)
# 2025-10-22 14:23:59 | INFO     | lmms_eval.api.task:build_all_requests:427 - Building contexts for mmmu_val on rank 0...
# 100% 300/300 [00:00<00:00, 8387.43it/s]
# 2025-10-22 14:23:59 | INFO     | lmms_eval.evaluator:evaluate:495 - Running generate_until requests
# Model Responding:   0% 0/300 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Model Responding: 100% 300/300 [11:35<00:00,  2.32s/it]
# Postprocessing: 100% 300/300 [00:00<00:00, 5518.92it/s]
# {'Overall-Art and Design': {'num': 60, 'acc': 0.63333}, 'Art': {'num': 30, 'acc': 0.53333}, 'Art_Theory': {'num': 30, 'acc': 0.73333}, 'Overall-Business': {'num': 30, 'acc': 0.53333}, 'Accounting': {'num': 30, 'acc': 0.53333}, 'Overall-Science': {'num': 60, 'acc': 0.21667}, 'Biology': {'num': 30, 'acc': 0.3}, 'Chemistry': {'num': 30, 'acc': 0.13333}, 'Overall-Health and Medicine': {'num': 60, 'acc': 0.5}, 'Basic_Medical_Science': {'num': 30, 'acc': 0.56667}, 'Clinical_Medicine': {'num': 30, 'acc': 0.43333}, 'Overall-Humanities and Social Science': {'num': 0, 'acc': 0}, 'Overall-Tech and Engineering': {'num': 90, 'acc': 0.32222}, 'Agriculture': {'num': 30, 'acc': 0.36667}, 'Architecture_and_Engineering': {'num': 30, 'acc': 0.36667}, 'Computer_Science': {'num': 30, 'acc': 0.23333}, 'Overall': {'num': 300, 'acc': 0.42}}
# fatal: not a git repository (or any of the parent directories): .git
# 2025-10-22 14:35:35 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_aggregated:188 - Saving results aggregated
# 2025-10-22 14:35:35 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_samples:287 - Saving samples to logs/Qwen__Qwen2-VL-2B-Instruct/20251022_222336_samples_mmmu_val.jsonl
# qwen2_vl (pretrained=Qwen/Qwen2-VL-2B-Instruct), gen_kwargs: (), limit: 300.0, num_fewshot: None, batch_size: 1
# |   Tasks   |Version|Filter|n-shot| Metric |   |Value|   |Stderr|
# |-----------|-------|------|-----:|--------|---|----:|---|------|
# |mmmu       |    N/A|      |      |        |   |     |   |      |
# | - mmmu_val|      0|none  |     0|mmmu_acc|↑  | 0.42|±  |   N/A|

# %% [markdown]
# Данный результат совпадает с заявленным на сайте hf: https://huggingface.co/Qwen/Qwen2-VL-2B-Instruct
#
# Советую ещё посмотреть в папку Logs, там появилась вся подробная информация о работе вашей модели

# %% [markdown]
# ## Выберем ещё пару бенчмарков

# %%
# !python3 -m accelerate.commands.launch \
            --num_processes=1 \
            -m lmms_eval \
            --model qwen2_vl \
            --model_args "pretrained=Qwen/Qwen2-VL-2B-Instruct" \
            --tasks mme,gqa \
            --batch_size 1 \
            --log_samples \
            --log_samples_suffix test \
            --output_path ./logs/ \
            --limit 300
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-10-22 21:38:17.097480: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761169097.118004    5769 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761169097.124282    5769 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761169097.140340    5769 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761169097.140368    5769 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761169097.140372    5769 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761169097.140375    5769 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-22 21:38:17.145469: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 21:38:24 | INFO     | __main__:cli_evaluate:311 - Verbosity set to INFO
# 2025-10-22 21:38:28 | INFO     | __main__:cli_evaluate_single:400 - Evaluation tracker args: {'output_path': './logs/', 'token': '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'}
# 2025-10-22 21:38:28 | WARNING  | __main__:cli_evaluate_single:430 -  --limit SHOULD ONLY BE USED FOR TESTING.REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2025-10-22 21:38:28 | INFO     | __main__:cli_evaluate_single:480 - Selected Tasks: ['gqa', 'mme']
# 2025-10-22 21:38:28 | INFO     | lmms_eval.evaluator:simple_evaluate:161 - Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:03<00:00,  1.70s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# README.md: 15.8kB [00:00, 349kB/s]
# testdev_balanced_instructions/testdev-00(…): 100% 2.09M/2.09M [00:02<00:00, 890kB/s]
# Generating testdev split: 100% 12578/12578 [00:00<00:00, 252457.08 examples/s]
# README.md: 100% 493/493 [00:00<00:00, 3.46MB/s]
# data/test-00003-of-00004-53ae1794f93b1e3(…): 100% 24.7M/24.7M [00:01<00:00, 17.0MB/s]
# data/test-00000-of-00004-a25dbe3b44c4fda(…): 100% 34.9M/34.9M [00:01<00:00, 23.6MB/s]
# data/test-00001-of-00004-7d22c7f1aba6fca(…): 100% 110M/110M [00:03<00:00, 30.5MB/s]
# data/test-00002-of-00004-594798fd3f5b029(…): 100% 695M/695M [00:09<00:00, 76.8MB/s]
# Generating test split: 100% 2374/2374 [00:15<00:00, 151.72 examples/s]
# 2025-10-22 21:39:16 | INFO     | lmms_eval.evaluator:evaluate:402 - Running on rank 0 (local rank 0)
# 2025-10-22 21:39:16 | INFO     | lmms_eval.evaluator_utils:from_taskdict:91 - No metadata found in task config for mme, using default n_shot=0
# 2025-10-22 21:39:16 | INFO     | lmms_eval.evaluator_utils:from_taskdict:91 - No metadata found in task config for gqa, using default n_shot=0
# 2025-10-22 21:39:16 | INFO     | lmms_eval.api.task:build_all_requests:427 - Building contexts for mme on rank 0...
# 100% 300/300 [00:00<00:00, 18633.35it/s]
# 2025-10-22 21:39:16 | INFO     | lmms_eval.api.task:build_all_requests:427 - Building contexts for gqa on rank 0...
# 100% 300/300 [00:00<00:00, 4073.77it/s]
# 2025-10-22 21:39:16 | INFO     | lmms_eval.evaluator:evaluate:495 - Running generate_until requests
# Model Responding:   0% 0/600 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Model Responding:   2% 10/600 [00:24<21:35,  2.20s/it]
# testdev_balanced_images/testdev-00000-of(…):   0% 0.00/65.6M [00:00<?, ?B/s]
# testdev_balanced_images/testdev-00000-of(…): 100% 65.6M/65.6M [00:01<00:00, 37.2MB/s]
#
# Generating testdev split:   0% 0/398 [00:00<?, ? examples/s]
# Generating testdev split: 100% 398/398 [00:00<00:00, 1796.29 examples/s]
# Model Responding: 100% 600/600 [24:57<00:00,  2.50s/it]
# Postprocessing: 100% 300/300 [00:00<00:00, 4698.25it/s]
# Postprocessing: 100% 300/300 [00:00<00:00, 1665.54it/s]
# 2025-10-22 22:04:15 | INFO     | utils:mme_aggregate_results:124 - code_reasoning: 95.00
# 2025-10-22 22:04:15 | INFO     | utils:mme_aggregate_results:124 - artwork: 142.69
# fatal: not a git repository (or any of the parent directories): .git
# 2025-10-22 22:04:15 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_aggregated:188 - Saving results aggregated
# 2025-10-22 22:04:15 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_samples:287 - Saving samples to logs/Qwen__Qwen2-VL-2B-Instruct/20251023_053828_samples_gqa.jsonl
# 2025-10-22 22:04:15 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_samples:287 - Saving samples to logs/Qwen__Qwen2-VL-2B-Instruct/20251023_053828_samples_mme.jsonl
# qwen2_vl (pretrained=Qwen/Qwen2-VL-2B-Instruct), gen_kwargs: (), limit: 300.0, num_fewshot: None, batch_size: 1
# |Tasks|Version|Filter|n-shot|       Metric       |   | Value  |   |Stderr|
# |-----|-------|------|-----:|--------------------|---|-------:|---|------|
# |gqa  |Yaml   |none  |     0|exact_match         |↑  |  0.5800|±  |0.0285|
# |mme  |Yaml   |none  |     0|mme_cognition_score |↑  | 95.0000|±  |   N/A|
# |mme  |Yaml   |none  |     0|mme_perception_score|↑  |142.6923|±  |   N/A|

# %% [markdown]
# # Соберём собственный бенч
#
# Сейчас мы пройдём весь путь создания бенча
# 1) Соберём данные
# 2) Оформим их на hf (удобно)
# 3) Напишем конфиг под lmms-eval
# 4) Прогоним модель
#
# Начнём со сбора данных, мы это сделаем через парсинг страницы steam с играми

# %%
import requests
from bs4 import BeautifulSoup
from PIL import Image
from io import BytesIO
import time

def get_steam_search_page_html(page):
    url = f"https://store.steampowered.com/search/?filter=topsellers&page={page}"
    resp = requests.get(url, timeout=15)
    resp.raise_for_status()
    return resp.text

def parse_steam_search_page(html):
    soup = BeautifulSoup(html, "html.parser")
    results = []
    for row in soup.select("a.search_result_row"):
        title_tag = row.select_one("span.title")
        logo_tag = row.select_one("div.search_capsule img")
        if title_tag and logo_tag and logo_tag.get("src"):
            title = title_tag.text.strip()
            img_url = logo_tag["src"]
            results.append({
                "title": title,
                "img_url": img_url
            })
    return results

def download_images(game_infos):
    games_with_images = []
    for info in game_infos:
        try:
            img_bytes = requests.get(info["img_url"], timeout=10).content
            img = Image.open(BytesIO(img_bytes)).convert("RGB")
            games_with_images.append({
                "title": info["title"],
                "image": img
            })
        except Exception as e:
            print(f"Ошибка с {info['title']}: {e}")
    return games_with_images

def scrape_n_steam_pages(n):
    all_infos = []
    for page in range(1, n+1):
        print(f"Запрашиваю страницу {page}...")
        html = get_steam_search_page_html(page)
        page_infos = parse_steam_search_page(html)
        print(f"  Найдено игр: {len(page_infos)}")
        all_infos.extend(page_infos)
        time.sleep(1)
    print("Скачиваем изображения...")
    games_final = download_images(all_infos)
    return games_final

games = scrape_n_steam_pages(40)
print(f"Всего игр: {len(games)}")
# Out:
# Запрашиваю страницу 1...
#   Найдено игр: 25
# Запрашиваю страницу 2...
#   Найдено игр: 25
# Запрашиваю страницу 3...
#   Найдено игр: 25
# Запрашиваю страницу 4...
#   Найдено игр: 25
# Запрашиваю страницу 5...
#   Найдено игр: 25
# Запрашиваю страницу 6...
#   Найдено игр: 25
# Запрашиваю страницу 7...
#   Найдено игр: 25
# Запрашиваю страницу 8...
#   Найдено игр: 25
# Запрашиваю страницу 9...
#   Найдено игр: 25
# Запрашиваю страницу 10...
#   Найдено игр: 25
# Запрашиваю страницу 11...
#   Найдено игр: 25
# Запрашиваю страницу 12...
#   Найдено игр: 25
# Запрашиваю страницу 13...
#   Найдено игр: 25
# Запрашиваю страницу 14...
#   Найдено игр: 25
# Запрашиваю страницу 15...
#   Найдено игр: 25
# Запрашиваю страницу 16...
#   Найдено игр: 25
# Запрашиваю страницу 17...
#   Найдено игр: 25
# Запрашиваю страницу 18...
#   Найдено игр: 25
# Запрашиваю страницу 19...
#   Найдено игр: 25
# Запрашиваю страницу 20...
#   Найдено игр: 25
# Запрашиваю страницу 21...
#   Найдено игр: 25
# Запрашиваю страницу 22...
#   Найдено игр: 25
# Запрашиваю страницу 23...
#   Найдено игр: 25
# Запрашиваю страницу 24...
#   Найдено игр: 25
# Запрашиваю страницу 25...
#   Найдено игр: 25
# Запрашиваю страницу 26...
#   Найдено игр: 25
# Запрашиваю страницу 27...
#   Найдено игр: 25
# Запрашиваю страницу 28...
#   Найдено игр: 25
# Запрашиваю страницу 29...
#   Найдено игр: 25
# Запрашиваю страницу 30...
#   Найдено игр: 25
# Запрашиваю страницу 31...
#   Найдено игр: 25
# Запрашиваю страницу 32...
#   Найдено игр: 25
# Запрашиваю страницу 33...
#   Найдено игр: 25
# Запрашиваю страницу 34...
#   Найдено игр: 25
# Запрашиваю страницу 35...
#   Найдено игр: 25
# Запрашиваю страницу 36...
#   Найдено игр: 25
# Запрашиваю страницу 37...
#   Найдено игр: 25
# Запрашиваю страницу 38...
#   Найдено игр: 25
# Запрашиваю страницу 39...
#   Найдено игр: 25
# Запрашиваю страницу 40...
#   Найдено игр: 25
# Скачиваем изображения...
# Всего игр: 1000

# %% [markdown]
# ### Теперь переведём данные hf формат и запушим в репу

# %%
from datasets import Dataset, Features, Value, Image as DatasetsImage

features = Features({
    "title": Value("string"),
    "image": DatasetsImage()
})

ds = Dataset.from_list(games, features=features)
print(ds[0])

ds.push_to_hub("tempqqq/steam-exact-match", private=False)
# Out:
# {'title': 'Counter-Strike 2', 'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=231x87 at 0x78B5616E25D0>}
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map:   0%|          | 0/250 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   6%|5         |  524kB / 9.20MB
# CommitInfo(commit_url='https://huggingface.co/datasets/tempqqq/steam-exact-match/commit/5505da8f20650cc4b8a6d280d0d17bd938609f31', commit_message='Upload dataset', commit_description='', oid='5505da8f20650cc4b8a6d280d0d17bd938609f31', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/tempqqq/steam-exact-match', endpoint='https://huggingface.co', repo_type='dataset', repo_id='tempqqq/steam-exact-match'), pr_revision=None, pr_num=None)

# %% [markdown]
# # Подготовим lmms-eval конфиг для нашего бенча
#
# Папка задачи lmms-eval выглядит следующим образом:
#
# ```
# task_name
# -- task_name.yaml
# -- utils.py
# ```
#
# task_name.yaml - основной конфиг задачи \
# utils.py - вспомогательные функции для подсчёта

# %%
# !mkdir /content/lmms-eval/lmms_eval/tasks/steam_exact_match/

# %%
# %%writefile /content/lmms-eval/lmms_eval/tasks/steam_exact_match/steam_exact_match.yaml
# dataset_path: tempqqq/steam-exact-match
# task: steam_exact_match
# test_split: train
# output_type: generate_until
# doc_to_visual: "image"
# doc_to_text: "Write only the name of the game"
# doc_to_target: "title"
# generation_kwargs:
#   max_new_tokens: 16
#   temperature: 0
#   top_p: 1.0
#   num_beams: 1
#   do_sample: false
# metric_list:
#   - metric: exact_match
#     aggregation: mean
#     higher_is_better: true
#     ignore_case: true
#     ignore_punctuation: true
# metadata:
#   - version: 0.0
# Out:
# Writing /content/lmms-eval/lmms_eval/tasks/steam_exact_match/steam_exact_match.yaml

# %%
# !python3 -m accelerate.commands.launch \
            --num_processes=1 \
            -m lmms_eval \
            --model qwen2_vl \
            --model_args "pretrained=Qwen/Qwen2-VL-2B-Instruct" \
            --tasks steam_exact_match \
            --batch_size 1 \
            --log_samples \
            --log_samples_suffix test \
            --output_path ./logs/
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-10-22 21:21:37.129060: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761168097.148608    1472 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761168097.154542    1472 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761168097.169277    1472 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761168097.169303    1472 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761168097.169307    1472 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761168097.169312    1472 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-22 21:21:37.173817: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 21:21:45 | INFO     | __main__:cli_evaluate:311 - Verbosity set to INFO
# 2025-10-22 21:21:47 | INFO     | __main__:cli_evaluate_single:400 - Evaluation tracker args: {'output_path': './logs/', 'token': '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'}
# 2025-10-22 21:21:47 | INFO     | __main__:cli_evaluate_single:480 - Selected Tasks: ['steam_exact_match']
# 2025-10-22 21:21:47 | INFO     | lmms_eval.evaluator:simple_evaluate:161 - Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# `torch_dtype` is deprecated! Use `dtype` instead!
# config.json: 1.20kB [00:00, 2.56MB/s]
# model.safetensors.index.json: 56.4kB [00:00, 122MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/3.99G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/429M [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:  16% 67.1M/429M [00:01<00:09, 37.2MB/s]
#
# model-00002-of-00002.safetensors:  22% 94.1M/429M [00:02<00:08, 37.7MB/s]
# model-00001-of-00002.safetensors:   0% 3.29M/3.99G [00:04<1:25:16, 779kB/s]
# model-00001-of-00002.safetensors:   0% 9.04M/3.99G [00:04<25:19, 2.62MB/s]
# model-00001-of-00002.safetensors:   1% 37.7M/3.99G [00:06<07:25, 8.87MB/s]
# model-00001-of-00002.safetensors:   2% 79.7M/3.99G [00:07<03:44, 17.4MB/s]
# model-00001-of-00002.safetensors:   3% 109M/3.99G [00:07<02:59, 21.7MB/s]
#
# model-00002-of-00002.safetensors:  38% 161M/429M [00:08<00:17, 15.7MB/s]
#
# model-00002-of-00002.safetensors:  53% 228M/429M [00:11<00:10, 19.2MB/s]
# model-00001-of-00002.safetensors:   4% 168M/3.99G [00:11<03:15, 19.5MB/s]
#
# model-00002-of-00002.safetensors:  69% 295M/429M [00:11<00:04, 29.4MB/s]
#
# model-00002-of-00002.safetensors:  84% 362M/429M [00:12<00:01, 37.5MB/s]
# model-00001-of-00002.safetensors:   5% 206M/3.99G [00:12<03:04, 20.5MB/s]
#
# model-00002-of-00002.safetensors: 100% 429M/429M [00:15<00:00, 28.0MB/s]
#
# model-00001-of-00002.safetensors:   7% 273M/3.99G [00:15<02:45, 22.5MB/s]
# model-00001-of-00002.safetensors:   9% 340M/3.99G [00:16<01:50, 33.2MB/s]
# model-00001-of-00002.safetensors:  10% 404M/3.99G [00:16<01:13, 48.7MB/s]
# model-00001-of-00002.safetensors:  12% 472M/3.99G [00:16<00:56, 61.9MB/s]
# model-00001-of-00002.safetensors:  14% 539M/3.99G [00:17<00:46, 73.5MB/s]
# model-00001-of-00002.safetensors:  15% 606M/3.99G [00:19<01:08, 49.7MB/s]
# model-00001-of-00002.safetensors:  17% 673M/3.99G [00:23<01:46, 31.2MB/s]
# model-00001-of-00002.safetensors:  20% 807M/3.99G [00:23<00:58, 54.6MB/s]
# model-00001-of-00002.safetensors:  22% 874M/3.99G [00:24<00:51, 60.6MB/s]
# model-00001-of-00002.safetensors:  24% 941M/3.99G [00:25<00:41, 73.5MB/s]
# model-00001-of-00002.safetensors:  25% 1.01G/3.99G [00:27<01:00, 49.0MB/s]
# model-00001-of-00002.safetensors:  29% 1.14G/3.99G [00:28<00:39, 72.7MB/s]
# model-00001-of-00002.safetensors:  30% 1.21G/3.99G [00:28<00:32, 84.9MB/s]
# model-00001-of-00002.safetensors:  31% 1.23G/3.99G [00:29<00:33, 82.1MB/s]
# model-00001-of-00002.safetensors:  33% 1.30G/3.99G [00:29<00:26, 103MB/s]
# model-00001-of-00002.safetensors:  34% 1.36G/3.99G [00:30<00:27, 95.7MB/s]
# model-00001-of-00002.safetensors:  36% 1.43G/3.99G [00:30<00:23, 111MB/s]
# model-00001-of-00002.safetensors:  38% 1.50G/3.99G [00:30<00:20, 120MB/s]
# model-00001-of-00002.safetensors:  39% 1.57G/3.99G [00:31<00:21, 112MB/s]
# model-00001-of-00002.safetensors:  41% 1.63G/3.99G [00:32<00:20, 115MB/s]
# model-00001-of-00002.safetensors:  43% 1.70G/3.99G [00:32<00:18, 122MB/s]
# model-00001-of-00002.safetensors:  44% 1.77G/3.99G [00:35<00:44, 50.0MB/s]
# model-00001-of-00002.safetensors:  46% 1.83G/3.99G [00:37<00:47, 45.8MB/s]
# model-00001-of-00002.safetensors:  48% 1.90G/3.99G [00:39<00:53, 38.8MB/s]
# model-00001-of-00002.safetensors:  49% 1.97G/3.99G [00:44<01:13, 27.6MB/s]
# model-00001-of-00002.safetensors:  51% 2.04G/3.99G [00:44<00:50, 38.4MB/s]
# model-00001-of-00002.safetensors:  53% 2.10G/3.99G [00:44<00:37, 50.1MB/s]
# model-00001-of-00002.safetensors:  54% 2.17G/3.99G [00:48<00:54, 33.6MB/s]
# model-00001-of-00002.safetensors:  58% 2.30G/3.99G [00:48<00:31, 52.8MB/s]
# model-00001-of-00002.safetensors:  59% 2.37G/3.99G [00:52<00:42, 37.9MB/s]
# model-00001-of-00002.safetensors:  61% 2.44G/3.99G [00:53<00:35, 43.7MB/s]
# model-00001-of-00002.safetensors:  62% 2.47G/3.99G [00:53<00:31, 48.1MB/s]
# model-00001-of-00002.safetensors:  64% 2.53G/3.99G [00:54<00:26, 55.1MB/s]
# model-00001-of-00002.safetensors:  65% 2.60G/3.99G [00:54<00:20, 67.9MB/s]
# model-00001-of-00002.safetensors:  67% 2.67G/3.99G [00:58<00:36, 36.6MB/s]
# model-00001-of-00002.safetensors:  69% 2.74G/3.99G [00:58<00:26, 47.7MB/s]
# model-00001-of-00002.safetensors:  70% 2.80G/3.99G [01:04<00:48, 24.4MB/s]
# model-00001-of-00002.safetensors:  72% 2.87G/3.99G [01:04<00:33, 33.8MB/s]
# model-00001-of-00002.safetensors:  74% 2.94G/3.99G [01:08<00:39, 26.6MB/s]
# model-00001-of-00002.safetensors:  75% 3.00G/3.99G [01:08<00:26, 37.1MB/s]
# model-00001-of-00002.safetensors:  77% 3.07G/3.99G [01:13<00:35, 25.5MB/s]
# model-00001-of-00002.safetensors:  79% 3.14G/3.99G [01:13<00:24, 34.9MB/s]
# model-00001-of-00002.safetensors:  80% 3.20G/3.99G [01:14<00:17, 44.1MB/s]
# model-00001-of-00002.safetensors:  82% 3.27G/3.99G [01:14<00:12, 59.4MB/s]
# model-00001-of-00002.safetensors:  83% 3.32G/3.99G [01:15<00:10, 61.3MB/s]
# model-00001-of-00002.safetensors:  85% 3.39G/3.99G [01:15<00:08, 67.8MB/s]
# model-00001-of-00002.safetensors:  87% 3.45G/3.99G [01:16<00:06, 86.7MB/s]
# model-00001-of-00002.safetensors:  88% 3.52G/3.99G [01:16<00:05, 91.8MB/s]
# model-00001-of-00002.safetensors:  90% 3.59G/3.99G [01:17<00:03, 102MB/s]
# model-00001-of-00002.safetensors:  92% 3.65G/3.99G [01:20<00:07, 42.3MB/s]
# model-00001-of-00002.safetensors:  93% 3.72G/3.99G [01:23<00:07, 36.8MB/s]
# model-00001-of-00002.safetensors:  95% 3.79G/3.99G [01:25<00:05, 34.8MB/s]
# model-00001-of-00002.safetensors:  97% 3.85G/3.99G [01:26<00:03, 43.9MB/s]
# model-00001-of-00002.safetensors: 100% 3.99G/3.99G [01:31<00:00, 43.7MB/s]
# Fetching 2 files: 100% 2/2 [01:31<00:00, 45.86s/it]
# Loading checkpoint shards: 100% 2/2 [00:17<00:00,  8.84s/it]
# generation_config.json: 100% 272/272 [00:00<00:00, 2.16MB/s]
# preprocessor_config.json: 100% 347/347 [00:00<00:00, 2.64MB/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# tokenizer_config.json: 4.19kB [00:00, 852kB/s]
# vocab.json: 2.78MB [00:00, 90.7MB/s]
# merges.txt: 1.67MB [00:00, 175MB/s]
# tokenizer.json: 7.03MB [00:00, 243MB/s]
# chat_template.json: 1.05kB [00:00, 482kB/s]
# README.md: 100% 311/311 [00:00<00:00, 2.42MB/s]
# data/train-00000-of-00001.parquet: 100% 9.20M/9.20M [00:03<00:00, 2.51MB/s]
# Generating train split: 100% 250/250 [00:00<00:00, 3009.54 examples/s]
# 2025-10-22 21:24:01 | INFO     | lmms_eval.evaluator:evaluate:402 - Running on rank 0 (local rank 0)
# 2025-10-22 21:24:01 | INFO     | lmms_eval.evaluator_utils:from_taskdict:91 - No metadata found in task config for steam_exact_match, using default n_shot=0
# 2025-10-22 21:24:01 | INFO     | lmms_eval.api.task:build_all_requests:427 - Building contexts for steam_exact_match on rank 0...
# 100% 250/250 [00:00<00:00, 2691.18it/s]
# 2025-10-22 21:24:01 | INFO     | lmms_eval.evaluator:evaluate:495 - Running generate_until requests
# Model Responding:   0% 0/250 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Model Responding: 100% 250/250 [01:45<00:00,  2.38it/s]
# Postprocessing: 100% 250/250 [00:00<00:00, 7079.62it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-10-22 21:25:47 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_aggregated:188 - Saving results aggregated
# 2025-10-22 21:25:47 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_samples:287 - Saving samples to logs/Qwen__Qwen2-VL-2B-Instruct/20251023_052147_samples_steam_exact_match.jsonl
# qwen2_vl (pretrained=Qwen/Qwen2-VL-2B-Instruct), gen_kwargs: (), limit: None, num_fewshot: None, batch_size: 1
# |      Tasks      |Version|Filter|n-shot|  Metric   |   |Value|   |Stderr|
# |-----------------|-------|------|-----:|-----------|---|----:|---|-----:|
# |steam_exact_match|Yaml   |none  |     0|exact_match|↑  |0.572|±  |0.0314|

# %% [markdown]
# # Поменяем формат задачи на Multiple Choice
#
# Подход выше с exact match - излишне строг, если модель напишет название чуть чуть по-другому, ей ответзасчитан не будет, давайте попробуем изменить формат
#
# Будем выбирать негативы/дистракторы/неправильные варианты ответа случайным образом

# %%
import random

def group_choices(games):
    options = []
    total = len(games)
    for idx, ans in enumerate(games):
        other_answers = [games[i]['title'] for i in range(total) if i != idx]
        sampled = random.sample(other_answers, min(3, len(other_answers)))
        group = [ans['title']] + sampled
        random.shuffle(group)
        options.append(group)
    return options


choices_all = group_choices(games)
print(choices_all[0], choices_all[1], sep='\n')
games = [
    {**game_info, 'choices': choices}
    for game_info, choices in zip(games, choices_all)
]
# Out:
# ['Gang Beasts', 'F1® 25', 'Golden Lap', 'Battlefield™ 6']
# ['Sea of Thieves: 2025 Edition', 'Steam Deck', 'Hogwarts Legacy: Dark Arts Pack', 'Football Manager 26']

# %%
from datasets import Dataset, Features, Value, Image as DatasetsImage, Sequence

features = Features({
    "title": Value("string"),
    "choices": Sequence(Value("string")),
    "image": DatasetsImage()
})

ds = Dataset.from_list(games, features=features)
print(ds[0])

ds.push_to_hub("tempqqq/steam_multiple_choice", private=False)
# Out:
# {'title': 'Battlefield™ 6', 'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=231x87 at 0x7A3F60C1C410>, 'choices': ['Gang Beasts', 'F1® 25', 'Golden Lap', 'Battlefield™ 6']}
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :  97%|#########6| 35.9MB / 37.0MB
# CommitInfo(commit_url='https://huggingface.co/datasets/tempqqq/steam_multiple_choice/commit/7a72ae145e3ca18b14f7d20eee3a0de7f1690bbb', commit_message='Upload dataset', commit_description='', oid='7a72ae145e3ca18b14f7d20eee3a0de7f1690bbb', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/tempqqq/steam_multiple_choice', endpoint='https://huggingface.co', repo_type='dataset', repo_id='tempqqq/steam_multiple_choice'), pr_revision=None, pr_num=None)

# %%
# !mkdir /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice

# %%
# %%writefile /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice/steam_multiple_choice.yaml
# dataset_path: tempqqq/steam_multiple_choice
# task: steam_multiple_choice
# test_split: train
# output_type: generate_until
# doc_to_visual: "image"
# doc_to_text: !function utils.prepare_input
# process_results: !function utils.process_results
# doc_to_target: "title"
# generation_kwargs:
#   max_new_tokens: 16
#   temperature: 0
#   top_p: 1.0
#   num_beams: 1
#   do_sample: false
# metric_list:
#   - metric: exact_match
#     aggregation: mean
#     higher_is_better: true
#     ignore_case: true
#     ignore_punctuation: true
# metadata:
#   - version: 0.0
# Out:
# Writing /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice/steam_multiple_choice.yaml

# %% [markdown]
# В этот раз придётся написать utils.py, чтобы задать в нём обработку нескольких вариантов ответа и финального результата
#
# Обратите внимание на то, как мы ссылаемся из основного конфига на функции из utils.py

# %%
# %%writefile /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice/utils.py
import numpy as np

def prepare_input(doc):
    letters = ['A', 'B', 'C', 'D']
    choices = [f"{letter}) {doc['choices'][i]}" for i, letter in enumerate(letters)]
    choices_str = '\n'.join(choices)
    prompt = "Choose the right name of the game. Write ONLY one letter A-E\n"
    return prompt + choices_str


def process_results(doc, result):
    letters = ['A', 'B', 'C', 'D']
    predicted_letter = result[0][0]
    if predicted_letter in letters:
        choice_idx = letters.index(predicted_letter)
    else:
        choice_idx = np.random.randint(4)
    return {
        'exact_match': doc['title'] == doc['choices'][choice_idx]
    }
# Out:
# Writing /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice/utils.py

# %%
# !python3 -m accelerate.commands.launch \
            --num_processes=1 \
            -m lmms_eval \
            --model qwen2_vl \
            --model_args "pretrained=Qwen/Qwen2-VL-2B-Instruct" \
            --tasks steam_multiple_choice \
            --batch_size 1 \
            --log_samples \
            --log_samples_suffix test \
            --output_path ./logs/ \
            --verbosity=DEBUG
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-10-23 13:16:40 | INFO     | __main__:cli_evaluate:311 - Verbosity set to DEBUG
# 2025-10-23 13:16:41 | DEBUG    | lmms_eval.tasks:_get_task_and_group:458 - `group` and `group_alias` keys in tasks' configs will no longer be used in the next release of lmms-eval. `tag` will be used to allow to call a collection of tasks just like `group`. `group` will be removed in order to not cause confusion with the new ConfigurableGroup which will be the offical way to create groups with addition of group-wide configuations.
# 2025-10-23 13:16:41 | DEBUG    | lmms_eval.tasks:_get_task_and_group:484 - File _default_template.yaml in /content/lmms-eval/lmms_eval/tasks/video-tt could not be loaded as a task or group
# 2025-10-23 13:16:43 | DEBUG    | lmms_eval.tasks:_get_task_and_group:484 - File illusionvqa.yaml in /content/lmms-eval/lmms_eval/tasks/illusionvqa could not be loaded as a task or group
# 2025-10-23 13:16:43 | INFO     | __main__:cli_evaluate_single:400 - Evaluation tracker args: {'output_path': './logs/', 'token': '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'}
# 2025-10-23 13:16:43 | INFO     | __main__:cli_evaluate_single:480 - Selected Tasks: ['steam_multiple_choice']
# 2025-10-23 13:16:43 | INFO     | lmms_eval.evaluator:simple_evaluate:161 - Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# Fetching 2 files: 100% 2/2 [00:00<00:00, 26886.56it/s]
# Loading checkpoint shards: 100% 2/2 [00:07<00:00,  3.53s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# README.md: 100% 350/350 [00:00<00:00, 1.81MB/s]
# data/train-00000-of-00001.parquet: 100% 37.0M/37.0M [00:01<00:00, 18.9MB/s]
# Generating train split: 100% 1000/1000 [00:00<00:00, 8374.41 examples/s]
# 2025-10-23 13:16:59 | INFO     | lmms_eval.evaluator:evaluate:402 - Running on rank 0 (local rank 0)
# 2025-10-23 13:16:59 | INFO     | lmms_eval.evaluator_utils:from_taskdict:91 - No metadata found in task config for steam_multiple_choice, using default n_shot=0
# 2025-10-23 13:16:59 | DEBUG    | lmms_eval.caching.cache:load_from_cache:34 - requests-steam_multiple_choice-0shot-rank0-world_size1-tokenizer is not cached, generating...
# 2025-10-23 13:16:59 | INFO     | lmms_eval.api.task:build_all_requests:427 - Building contexts for steam_multiple_choice on rank 0...
# 100% 1000/1000 [00:00<00:00, 18766.12it/s]
# 2025-10-23 13:16:59 | DEBUG    | lmms_eval.evaluator:evaluate:460 - Task: steam_multiple_choice; number of requests on this rank: 1000
# 2025-10-23 13:16:59 | INFO     | lmms_eval.evaluator:evaluate:495 - Running generate_until requests
# Model Responding:   0% 0/1000 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Model Responding: 100% 1000/1000 [07:35<00:00,  2.19it/s]
# Postprocessing: 100% 1000/1000 [00:00<00:00, 12986.14it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-10-23 13:24:35 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_aggregated:188 - Saving results aggregated
# 2025-10-23 13:24:35 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_samples:287 - Saving samples to logs/Qwen__Qwen2-VL-2B-Instruct/20251023_211643_samples_steam_multiple_choice.jsonl
# qwen2_vl (pretrained=Qwen/Qwen2-VL-2B-Instruct), gen_kwargs: (), limit: None, num_fewshot: None, batch_size: 1
# |        Tasks        |Version|Filter|n-shot|  Metric   |   |Value|   |Stderr|
# |---------------------|-------|------|-----:|-----------|---|----:|---|-----:|
# |steam_multiple_choice|Yaml   |none  |     0|exact_match|↑  |    1|±  |     0|

# %% [markdown]
# Выглядит не очень информативно...

# %% [markdown]
#  # Попробуем улучшить дистракторы
#
#  Есть подозрение, что случайным образом подобранные варианты ответа делают ответ уж слишком очевидным
#
#  Давайте переформируем варианты ответа по следующему принципу:
#  1) Возьмём эмбеддинги всех ответов
#  2) Для каждого правильного ответа будем брать 3 ближайших других ответов в качестве негативов

# %%
# !pip install -U sentence_transformers

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import torch


class DistractorBuilder:
    def __init__(self, model_name='ai-forever/FRIDA'):
        self.emb_model = SentenceTransformer(model_name)

    def _choice_2d(self, data, size, replace):
        res_data = []
        for i, line in enumerate(data):
            res_data += [np.random.choice(line, size=size, replace=replace)]


        return np.array(res_data)

    def build_nearest(self, answers, limits_min=None, limits_max=None,
                      coefs_min=None, coefs_max=None, num_choices=4,
                      duplicates=False, groups=None, sentence_prefix='categorize_topic:'):
        groups = [0] * len(answers) if groups is None else groups
        groups = np.array(groups)
        unique_groups = set(groups)

        limits_min = limits_min if type(limits_min) == dict else {g: limits_min for g in unique_groups}
        limits_max = limits_max if type(limits_max) == dict else {g: limits_max for g in unique_groups}
        coefs_min = coefs_min if type(coefs_min) == dict else {g: coefs_min for g in unique_groups}
        coefs_max = coefs_max if type(coefs_max) == dict else {g: coefs_max for g in unique_groups}

        res_dict = {}
        for cur_group in unique_groups:
            limit_min, limit_max = limits_min[cur_group], limits_max[cur_group]
            coef_min, coef_max = coefs_min[cur_group], coefs_max[cur_group]
            cur_answers = np.array(answers)[groups == cur_group]
            cur_answers = [cur_answer.strip(" .,;:!?") for cur_answer in cur_answers]

            unique_choices, unique_idx = np.unique(
                cur_answers,
                return_index=True
            )

            choices_embs = self.emb_model.encode(
                [sentence_prefix + choice for choice in cur_answers],
                convert_to_tensor=True
            )

            sim_scores = choices_embs @ choices_embs[unique_idx].T
            indices = torch.argsort(sim_scores, dim=1, descending=True).cpu()

            min_idx = int(coef_min * len(unique_choices)) if coef_min is not None else 1
            min_idx = limit_min if (limit_min is not None and limit_min > min_idx) else min_idx
            max_idx = int(coef_max * len(unique_choices)) if coef_max is not None else len(answers)
            max_idx = limit_max if (limit_max is not None and limit_max < max_idx) else max_idx

            answer_indices = indices[:, 0].unsqueeze(-1).numpy()
            distractors_indices = self._choice_2d(indices[:, min_idx:max_idx], size=num_choices - 1, replace=False)
            choices = unique_choices[np.concatenate([distractors_indices, answer_indices], axis=1)].tolist()

            res_dict[cur_group] = choices

        res_list = []
        for group in groups:
            res_list.append(res_dict[group].pop(0))
        return res_list

# %%
words = [
    "Рецепт", "Сковорода", "Приправа", "Выпечка", "Маринад",
    "Тренировка", "Мяч", "Стадион", "Победа", "Спортсмен",
    "Процессор", "Алгоритм", "Байт", "Монитор", "Клавиатура",
    "Мелодия", "Гитара", "Нота", "Оркестр", "Ритм"
]

distractor_builder = DistractorBuilder('ai-forever/FRIDA')
# Построить 4 ближайших дистрактора для каждого слова
result = distractor_builder.build_nearest(words, num_choices=4, limits_max=4)
print(result)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# [['Маринад', 'Выпечка', 'Приправа', 'Рецепт'], ['Приправа', 'Выпечка', 'Рецепт', 'Сковорода'], ['Выпечка', 'Рецепт', 'Маринад', 'Приправа'], ['Сковорода', 'Приправа', 'Рецепт', 'Выпечка'], ['Выпечка', 'Рецепт', 'Приправа', 'Маринад'], ['Мяч', 'Стадион', 'Спортсмен', 'Тренировка'], ['Тренировка', 'Спортсмен', 'Стадион', 'Мяч'], ['Победа', 'Спортсмен', 'Мяч', 'Стадион'], ['Стадион', 'Тренировка', 'Мяч', 'Победа'], ['Тренировка', 'Мяч', 'Стадион', 'Спортсмен'], ['Клавиатура', 'Алгоритм', 'Байт', 'Процессор'], ['Байт', 'Процессор', 'Клавиатура', 'Алгоритм'], ['Клавиатура', 'Алгоритм', 'Процессор', 'Байт'], ['Процессор', 'Клавиатура', 'Байт', 'Монитор'], ['Байт', 'Монитор', 'Процессор', 'Клавиатура'], ['Гитара', 'Ритм', 'Оркестр', 'Мелодия'], ['Ритм', 'Мелодия', 'Оркестр', 'Гитара'], ['Ритм', 'Мелодия', 'Клавиатура', 'Нота'], ['Мелодия', 'Ритм', 'Гитара', 'Оркестр'], ['Гитара', 'Оркестр', 'Мелодия', 'Ритм']]

# %%
titles_only = [game['title'] for game in games]
choices_only = distractor_builder.build_nearest(titles_only, num_choices=4, limits_max=4)
print('\n'.join([str(choices) for choices in choices_only][:5]))

games = [
    {**game_info, 'choices': choices}
    for game_info, choices in zip(games, choices_only)
]
# Out:
# ['Counter-Strike 2', "Tom Clancy's Rainbow Six® Siege X", 'Call of Duty: United Offensive', 'Battlefield™ 6']
# ['EA SPORTS FC™ 25', 'eFootball™', 'EA SPORTS FC™ 26', 'Football Manager 26']
# ['GTFO', 'REMATCH', 'Shamania', 'Dispatch']
# ['Jurassic World Evolution 2', 'Jurassic World Evolution 3: Badlands Set', 'Jurassic World Evolution 2: Camp Cretaceous Dinosaur Pack', 'Jurassic World Evolution 3']
# ['Star Birds', 'V Rising', 'Victoria 3', 'RV There Yet']

# %% [markdown]
# Выглядит значительно лучше/сложнее. Посмотрим на качество модели

# %%
from datasets import Dataset, Features, Value, Image as DatasetsImage, Sequence

features = Features({
    "title": Value("string"),
    "choices": Sequence(Value("string")),
    "image": DatasetsImage()
})

ds = Dataset.from_list(games, features=features)
print(ds[0])

ds.push_to_hub("tempqqq/steam_multiple_choice_improved", private=False)
# Out:
# {'title': 'Battlefield™ 6', 'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=231x87 at 0x7A3F60A7AA50>, 'choices': ['Counter-Strike 2', "Tom Clancy's Rainbow Six® Siege X", 'Call of Duty: United Offensive', 'Battlefield™ 6']}
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   1%|          |  267kB / 37.0MB
# CommitInfo(commit_url='https://huggingface.co/datasets/tempqqq/steam_multiple_choice_improved/commit/ebccf46e8e61174278227f41fe37a5eea662e8e1', commit_message='Upload dataset', commit_description='', oid='ebccf46e8e61174278227f41fe37a5eea662e8e1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/tempqqq/steam_multiple_choice_improved', endpoint='https://huggingface.co', repo_type='dataset', repo_id='tempqqq/steam_multiple_choice_improved'), pr_revision=None, pr_num=None)

# %%
# !mkdir /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice_improved/

# %%
# %%writefile /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice_improved/steam_multiple_choice_improved.yaml
# dataset_path: tempqqq/steam_multiple_choice_improved
# task: steam_multiple_choice_improved
# test_split: train
# output_type: generate_until
# doc_to_visual: "image"
# doc_to_text: !function utils.prepare_input
# process_results: !function utils.process_results
# doc_to_target: "title"
# generation_kwargs:
#   max_new_tokens: 16
#   temperature: 0
#   top_p: 1.0
#   num_beams: 1
#   do_sample: false
# metric_list:
#   - metric: exact_match
#     aggregation: mean
#     higher_is_better: true
#     ignore_case: true
#     ignore_punctuation: true
# metadata:
#   - version: 0.0
# Out:
# Overwriting /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice_improved/steam_multiple_choice_improved.yaml

# %%
# %%writefile /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice_improved/utils.py
import numpy as np

def prepare_input(doc):
    letters = ['A', 'B', 'C', 'D']
    choices = [f"{letter}) {doc['choices'][i]}" for i, letter in enumerate(letters)]
    choices_str = '\n'.join(choices)
    prompt = "Choose the right name of the game. Write ONLY one letter A-E\n"
    return prompt + choices_str


def process_results(doc, result):
    letters = ['A', 'B', 'C', 'D']
    predicted_letter = result[0][0]
    if predicted_letter in letters:
        choice_idx = letters.index(predicted_letter)
    else:
        choice_idx = np.random.randint(4)
    return {
        'exact_match': doc['title'] == doc['choices'][choice_idx]
    }
# Out:
# Overwriting /content/lmms-eval/lmms_eval/tasks/steam_multiple_choice_improved/utils.py

# %%
# !python3 -m accelerate.commands.launch \
            --num_processes=1 \
            -m lmms_eval \
            --model qwen2_vl \
            --model_args "pretrained=Qwen/Qwen2-VL-2B-Instruct" \
            --tasks steam_multiple_choice_improved \
            --batch_size 1 \
            --log_samples \
            --log_samples_suffix test \
            --output_path ./logs/ \
            --verbosity=DEBUG
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-10-23 13:01:31 | INFO     | __main__:cli_evaluate:311 - Verbosity set to DEBUG
# 2025-10-23 13:01:31 | DEBUG    | lmms_eval.tasks:_get_task_and_group:458 - `group` and `group_alias` keys in tasks' configs will no longer be used in the next release of lmms-eval. `tag` will be used to allow to call a collection of tasks just like `group`. `group` will be removed in order to not cause confusion with the new ConfigurableGroup which will be the offical way to create groups with addition of group-wide configuations.
# 2025-10-23 13:01:31 | DEBUG    | lmms_eval.tasks:_get_task_and_group:484 - File _default_template.yaml in /content/lmms-eval/lmms_eval/tasks/video-tt could not be loaded as a task or group
# 2025-10-23 13:01:33 | DEBUG    | lmms_eval.tasks:_get_task_and_group:484 - File illusionvqa.yaml in /content/lmms-eval/lmms_eval/tasks/illusionvqa could not be loaded as a task or group
# 2025-10-23 13:01:33 | INFO     | __main__:cli_evaluate_single:400 - Evaluation tracker args: {'output_path': './logs/', 'token': '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'}
# 2025-10-23 13:01:33 | INFO     | __main__:cli_evaluate_single:480 - Selected Tasks: ['steam_multiple_choice_improved']
# 2025-10-23 13:01:33 | INFO     | lmms_eval.evaluator:simple_evaluate:161 - Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# Fetching 2 files: 100% 2/2 [00:00<00:00, 28149.69it/s]
# Loading checkpoint shards: 100% 2/2 [00:07<00:00,  3.65s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# README.md: 100% 350/350 [00:00<00:00, 1.89MB/s]
# data/train-00000-of-00001.parquet: 100% 37.0M/37.0M [00:02<00:00, 15.2MB/s]
# Generating train split: 100% 1000/1000 [00:00<00:00, 6424.80 examples/s]
# 2025-10-23 13:01:50 | INFO     | lmms_eval.evaluator:evaluate:402 - Running on rank 0 (local rank 0)
# 2025-10-23 13:01:50 | INFO     | lmms_eval.evaluator_utils:from_taskdict:91 - No metadata found in task config for steam_multiple_choice_improved, using default n_shot=0
# 2025-10-23 13:01:50 | DEBUG    | lmms_eval.caching.cache:load_from_cache:34 - requests-steam_multiple_choice_improved-0shot-rank0-world_size1-tokenizer is not cached, generating...
# 2025-10-23 13:01:50 | INFO     | lmms_eval.api.task:build_all_requests:427 - Building contexts for steam_multiple_choice_improved on rank 0...
# 100% 1000/1000 [00:00<00:00, 12237.67it/s]
# 2025-10-23 13:01:50 | DEBUG    | lmms_eval.evaluator:evaluate:460 - Task: steam_multiple_choice_improved; number of requests on this rank: 1000
# 2025-10-23 13:01:50 | INFO     | lmms_eval.evaluator:evaluate:495 - Running generate_until requests
# Model Responding:   0% 0/1000 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Model Responding: 100% 1000/1000 [07:11<00:00,  2.32it/s]
# Postprocessing: 100% 1000/1000 [00:00<00:00, 11863.63it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-10-23 13:09:02 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_aggregated:188 - Saving results aggregated
# 2025-10-23 13:09:02 | INFO     | lmms_eval.loggers.evaluation_tracker:save_results_samples:287 - Saving samples to logs/Qwen__Qwen2-VL-2B-Instruct/20251023_210133_samples_steam_multiple_choice_improved.jsonl
# qwen2_vl (pretrained=Qwen/Qwen2-VL-2B-Instruct), gen_kwargs: (), limit: None, num_fewshot: None, batch_size: 1
# |            Tasks             |Version|Filter|n-shot|  Metric   |   |Value|   |Stderr|
# |------------------------------|-------|------|-----:|-----------|---|----:|---|-----:|
# |steam_multiple_choice_improved|Yaml   |none  |     0|exact_match|↑  | 0.95|±  |0.0069|

# %% [markdown]
# ### Стало лучше, но будто бы незначительно. С чем это может быть связано?
